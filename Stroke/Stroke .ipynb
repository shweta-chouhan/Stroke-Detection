# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
avg = data['bmi'].mean()
avg
# Out:
# 28.893236911794666

# %%
data.bmi = data['bmi'].fillna(avg)

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data['work_type'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='work_type', ylabel='count'>

# %%
sns.countplot(data['Residence_type'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Residence_type', ylabel='count'>

# %%
sns.countplot(data['smoking_status'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>

# %%
sns.countplot(data['stroke'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='stroke', ylabel='count'>

# %%
sns.countplot(data['ever_married'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ever_married', ylabel='count'>

# %%
min_avg_glucose_level = min(data.avg_glucose_level)
max_avg_glucose_level = max(data.avg_glucose_level)
print(min_avg_glucose_level)
print(max_avg_glucose_level)
# Out:
# 55.12
# 271.74

# %%
sns.distplot(data['age'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(data['avg_glucose_level'])
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='Density'>

# %% [markdown]
# #### MAPPING OF CATEGORICAL VARIABLES

# %%
data['work_type'] = data['work_type'].map({'Private':0, 'Self-employed': 1, 'Govt_job':2, 'children':3, 'Never_worked':4})

# %%
data['gender'] = data['gender'].map({'Male':0, 'Female':1})
data['Residence_type'] = data['Residence_type'].map({'Urban':0, 'Rural':1})
data['smoking_status'] = data['smoking_status'].map({'formerly smoked':0, 'never smoked':1, 'smokes':2, 'Unknown':3})
data['ever_married'] = data['ever_married'].map({'Yes':0, 'No':1})

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0   9046     0.0  67.0             0              1             0          0
# 1  51676     1.0  61.0             0              0             0          1
# 2  31112     0.0  80.0             0              1             0          0
# 3  60182     1.0  49.0             0              0             0          0
# 4   1665     1.0  79.0             1              0             0          1
#
#    Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# 0               0             228.69  36.600000               0       1
# 1               1             202.21  28.893237               1       1
# 2               1             105.92  32.500000               1       1
# 3               0             171.23  34.400000               2       1
# 4               1             174.12  24.000000               1       1

# %%
data.isnull().sum()
# Out:
# id                   0
# gender               1
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.heatmap(data.corr(method='pearson'), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=data['age'], y=data['avg_glucose_level'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='avg_glucose_level'>

# %%
sns.catplot(x='heart_disease',y='age', hue="work_type", kind="bar", data=data)

# %%
sns.catplot(x="smoking_status", y="stroke", hue="work_type", kind="bar", data=data)

# %%
sns.catplot(x="hypertension", y="stroke", hue="work_type", kind="bar", data=data)

# %%
sns.catplot(x="Residence_type", y="stroke", hue="work_type", kind="bar", data=data)

# %%
sns.catplot(x='stroke', y="avg_glucose_level", kind="box", data=data)

# %%
sns.catplot(x='stroke', y="age", hue = 'gender', kind="box", data=data)

# %%
sns.catplot(x='stroke', y="age", hue = 'work_type', kind="box", data=data)

# %% [markdown]
# ### Machine Learning

# %%
features = ['id','age',
 'hypertension',
 'heart_disease',
 'ever_married',
 'Residence_type',
 'avg_glucose_level',
 'bmi',
 'gender',
 'work_type',
 'smoking_status']

label = ['stroke']

X = data[features]
y = data[label]

# %%
X.isnull().sum()
# Out:
# id                   0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# gender               1
# work_type            0
# smoking_status       0
# dtype: int64

# %%
X.gender=(X.gender.fillna(1))
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
X.isnull().sum()
# Out:
# id                   0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# gender               0
# work_type            0
# smoking_status       0
# dtype: int64

# %%
#TREATING IMBALANCE CLASS USING SMOTE
from imblearn.over_sampling import SMOTE

smote = SMOTE()
x_smote, y_smote = smote.fit_resample(X, y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.33,random_state=42)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
testing = X_test['id'] #taking ID column for the purpose of submission
testing
# Out:
# 315     41940
# 534     71808
# 1427     5984
# 9125    12100
# 6025    71651
#         ...
# 3065    46455
# 8270     7861
# 6574    31438
# 2487    44325
# 620     34558
# Name: id, Length: 1605, dtype: int64

# %%
X_train = X_train.drop(columns=['id'])
X_test = X_test.drop(columns=['id'])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.04208455, -0.30999289, -0.21897149, ...,  0.93469749,
#         -0.61487497,  0.71613885],
#        [ 0.24492776, -0.30999289, -0.21897149, ...,  0.64566167,
#         -0.61487497, -0.24495992],
#        [ 0.36518583, -0.30999289, -0.21897149, ...,  0.93469749,
#         -0.61487497, -1.2060587 ],
#        ...,
#        [ 0.51961852, -0.30999289, -0.21897149, ...,  0.93469749,
#         -0.61487497, -1.2060587 ],
#        [-0.41380035, -0.30999289, -0.21897149, ...,  0.93469749,
#         -0.61487497,  0.71613885],
#        [ 0.88231432, -0.30999289, -0.21897149, ...,  0.93469749,
#          0.4709929 , -0.24495992]])

# %%
X_test
# Out:
# array([[ 0.09730888, -0.30999289,  4.56680465, ..., -1.27538153,
#         -0.61487497, -1.2060587 ],
#        [-1.62187669, -0.30999289, -0.21897149, ...,  0.93469749,
#         -0.61487497,  1.67723763],
#        [-1.38955431, -0.30999289, -0.21897149, ..., -1.27538153,
#         -0.61487497,  0.71613885],
#        ...,
#        [ 0.74464949, -0.30999289, -0.21897149, ..., -1.14479411,
#          0.4709929 , -1.2060587 ],
#        [ 1.07306284, -0.30999289, -0.21897149, ..., -1.27538153,
#          0.4709929 ,  0.71613885],
#        [-1.01783852, -0.30999289, -0.21897149, ..., -1.27538153,
#         -0.61487497, -0.24495992]])

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# c:\users\shweta chouhan\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
y_pred_log_reg = log_reg.predict(X_test)
y_pred_log_reg
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.metrics import f1_score, roc_auc_score,accuracy_score,confusion_matrix, precision_recall_curve, auc, roc_curve, recall_score, classification_report 
classification_report = classification_report(y_test, y_pred_log_reg)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       803
#            1       0.79      0.86      0.82       802
#
#     accuracy                           0.82      1605
#    macro avg       0.82      0.82      0.82      1605
# weighted avg       0.82      0.82      0.82      1605

# %%
auc = roc_auc_score(y_test, y_pred_log_reg)
auc
# Out:
# 0.8180933096896612

# %%
cm = confusion_matrix(y_test, y_pred_log_reg)
cm
# Out:
# array([[625, 178],
#        [114, 688]], dtype=int64)

# %%
predicted_probab_log = log_reg.predict_proba(X_test)
predicted_probab_log = predicted_probab_log[:, 1]
fpr, tpr, _ = roc_curve(y_test, predicted_probab_log)

# %%
# ROC Curve
from matplotlib import pyplot
pyplot.plot(fpr, tpr, marker='.', label='Logistic Regression')
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
pyplot.show()

# %%
rfc_predict = rfc.predict(X_test)
roc_auc_score(y_test, rfc_predict)
# Out:
# 0.9152694229556867

# %%
cm = confusion_matrix(y_test, rfc_predict)
cm
# Out:
# array([[729,  74],
#        [ 62, 740]], dtype=int64)

# %%
tn = cm[0,0]
fp = cm[0,1]
tp = cm[1,1]
fn = cm[1,0]
accuracy  = (tp + tn) / (tp + fp + tn + fn)
precision = tp / (tp + fp)
recall    = tp / (tp + fn)
f1score  = 2 * precision * recall / (precision + recall)
print(f1score)
# Out:
# 0.9158415841584158

# %%
predicted_probab = predicted_probab[:, 1]

# %%
fpr, tpr, _ = roc_curve(y_test, predicted_probab)

# %%
pyplot.plot(fpr, tpr, marker='.', color='red', label='Random Forest')
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
pyplot.show()

# %%
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-144-5943d1bfe3f1> in <module>
# ----> 1 import xgboost as xgb
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
model = xgb.XGBClassifier()
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-5b96991adcc1> in <module>
# ----> 1 model = xgb.XGBClassifier()
#       2 model.fit(X_train,y_train)
#
# NameError: name 'xgb' is not defined

# %%
y_pred1 = model.predict(X_test)
roc_auc_score(y_test, y_pred1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-26f247086a27> in <module>
# ----> 1 y_pred1 = model.predict(X_test)
#       2 roc_auc_score(y_test, y_pred1)
#
# NameError: name 'model' is not defined

# %%
cm = confusion_matrix(y_test, y_pred1)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-943398593219> in <module>
# ----> 1 cm = confusion_matrix(y_test, y_pred1)
#       2 cm
#
# NameError: name 'y_pred1' is not defined

# %%
tn = cm[0,0]
fp = cm[0,1]
tp = cm[1,1]
fn = cm[1,0]
accuracy  = (tp + tn) / (tp + fp + tn + fn)
precision = tp / (tp + fp)
recall    = tp / (tp + fn)
f1score  = 2 * precision * recall / (precision + recall)
print(f1score)
# Out:
# 0.9170305676855895

# %%
predicted_probab = model.predict_proba(X_test)
predicted_probab = predicted_probab[:, 1]
fpr, tpr, _ = roc_curve(y_test, predicted_probab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-446103e9920b> in <module>
# ----> 1 predicted_probab = model.predict_proba(X_test)
#       2 predicted_probab = predicted_probab[:, 1]
#       3 fpr, tpr, _ = roc_curve(y_test, predicted_probab)
#
# NameError: name 'model' is not defined

# %%
pyplot.plot(fpr, tpr, marker='.', color='green',label='XGB Classifier')
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
pyplot.show()

# %%
my_submission = pd.DataFrame({'Id': testing, 'Stroke': y_pred1})
my_submission.to_csv('submission.csv', index=False)
my_submission = pd.read_csv('submission.csv')
my_submission
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-c4c2d61cbba0> in <module>
# ----> 1 my_submission = pd.DataFrame({'Id': testing, 'Stroke': y_pred1})
#       2 my_submission.to_csv('submission.csv', index=False)
#       3 my_submission = pd.read_csv('submission.csv')
#       4 my_submission
#
# NameError: name 'y_pred1' is not defined

# %%
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
